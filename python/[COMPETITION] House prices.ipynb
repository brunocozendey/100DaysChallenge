# %% [markdown]
# Import teste datam

# %%
import pandas as pd

file = "/home/bruno/Documents/Python/100DaysChallenge/python/input/house_prices/train.csv"
raw_data = pd.read_csv(file) 
raw_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
raw_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
y = raw_data.SalePrice

# %%
y.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# Selecionar caracterisitacas do apt.
# Primeiro vou tentar com todas e ver a precisão.
# Verifiquei aqui, que só pode ser utilizado valores numéricos, se quiser usar por exemplo se uma rua gera um determinado preço, não é com o modelo que aprendi até agora.

# %% [markdown]
# Um ideia para tratar os campos que não são numeros é tratalos como numero, requer um trabalho maior e posso fazer depois. Ex. se for sim ou não, colocar S = 1 e N = 0

# %%
caract = ['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition']

# %%
# Apenas dados dunmericos nas caracteristicas
caract = ['MSSubClass','LotFrontage', 'LotArea','YearBuilt', 'YearRemodAdd','BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GarageArea', 
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea','MiscVal', 'MoSold', 'YrSold']

# %%
X = raw_data[caract]
X.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea    YearBuilt  YearRemodAdd  \
# count  1460.000000  1201.000000    1460.000000  1460.000000   1460.000000
# mean     56.897260    70.049958   10516.828082  1971.267808   1984.865753
# std      42.300571    24.284752    9981.264932    30.202904     20.645407
# min      20.000000    21.000000    1300.000000  1872.000000   1950.000000
# 25%      20.000000    59.000000    7553.500000  1954.000000   1967.000000
# 50%      50.000000    69.000000    9478.500000  1973.000000   1994.000000
# 75%      70.000000    80.000000   11601.500000  2000.000000   2004.000000
# max     190.000000   313.000000  215245.000000  2010.000000   2010.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466
# std     161.319273   441.866955   438.705324   386.587738   436.528436
# ...

# %%
X.head(100)
# Out:
#     MSSubClass  LotFrontage  LotArea  YearBuilt  YearRemodAdd  BsmtFinSF2  \
# 0           60         65.0     8450       2003          2003           0
# 1           20         80.0     9600       1976          1976           0
# 2           60         68.0    11250       2001          2002           0
# 3           70         60.0     9550       1915          1970           0
# 4           60         84.0    14260       2000          2000           0
# ..         ...          ...      ...        ...           ...         ...
# 95          60          NaN     9765       1993          1993           0
# 96          20         78.0    10264       1999          1999           0
# 97          20         73.0    10921       1965          1965           0
# 98          30         85.0    10625       1920          1950           0
# 99          20         77.0     9320       1959          1959           0
#
#     BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  GarageArea  EnclosedPorch  \
# ...

# %% [markdown]
# Testando modelos
#
# 1 - Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_absolute_error

# Aliminando os NaN
X2 = np.nan_to_num(X)

#Dividindo dados
train_X, val_X, train_y, val_y = train_test_split(X2, y, random_state = 0)

# Define model. Specify a number for random_state to ensure same results each run
model1 = DecisionTreeRegressor(random_state=1)

# Fit model
model1.fit(train_X,train_y)

val_predictions = model1.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))

def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

for max_leaf_nodes in [5, 50, 500, 5000, 50000,500000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# 29733.44383561644
# Max leaf nodes: 5  		 Mean Absolute Error:  35757
# Max leaf nodes: 50  		 Mean Absolute Error:  29655
# Max leaf nodes: 500  		 Mean Absolute Error:  31047
# Max leaf nodes: 5000  		 Mean Absolute Error:  31150
# Max leaf nodes: 50000  		 Mean Absolute Error:  31150
# Max leaf nodes: 500000  		 Mean Absolute Error:  31150

# %%
from sklearn.ensemble import RandomForestRegressor

forest_model = RandomForestRegressor(random_state=5)
forest_model.fit(train_X, train_y)
preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, preds))
# Out:
# 20861.17567123288

# %%
print(preds[1])
# Out:
# 143954.84

# %%
print(val_y[1])
# Out:
# 181500

# %% [markdown]
# ## Usando os dados de teste

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

file = "/home/bruno/Documents/Python/100DaysChallenge/python/input/house_prices/test.csv"
raw_data = pd.read_csv(file) 

caract = ['MSSubClass','LotFrontage', 'LotArea','YearBuilt', 'YearRemodAdd','BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GarageArea', 
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea','MiscVal', 'MoSold', 'YrSold']

XT = raw_data[caract]

forest_model = RandomForestRegressor(random_state=5)
preds = forest_model.predict(XT)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-122-dd14a04289fb> in <module>()
#      11
#      12 forest_model = RandomForestRegressor(random_state=5)
# ---> 13 preds = forest_model.predict(XT)
#      14
#
# /home/bruno/.local/lib/python3.6/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     762             The predicted values.
#     763         """
# --> 764         check_is_fitted(self)
#     765         # Check data
#     766         X = self._validate_X_predict(X)
#
# /home/bruno/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     965
#     966     if not attrs:
# --> 967         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     968
#     969
#
# ...
